# %%
import numpy as np
import cv2
import os 
import shutil
from PIL import Image
import re
import matplotlib.pyplot as plt

# %%
image = Image.open('crop_row_001.JPG')
 
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (320, 240)
# RGB

# %%
img_numpy = np.load('crop_row_001.npy')
plt.imshow(img_numpy)

# %%
dir1 = "/Users/hasanadmin/Documents/Labels/"

for file in os.listdir(dir1):
    if file.endswith(".npy"):
        array_numpy = np.load(file)
        img_numpy = Image.fromarray(array_numpy, "RGB")

        numerical = re.findall(r'\d+', file)[0]
        #cv2.imwrite(f'/Users/hasanadmin/Documents/Labels/label_images/image_{numerical}.png',img_numpy)

# %%
# Get list of all files in a given directory
files =  filter( lambda x: os.path.isfile(os.path.join(parent_dir, x)),
                        os.listdir(parent_dir) )

# %%
for file_name in files:
    img_numpy = np.load(file_name)
    numerical = re.search(r'[0-9]', crop_row_label)
    print(numerical)

# %%
img = Image.fromarray(img_numpy, "RGB")
    result = cv2.imwrite(r'\label_images\dog.'+ numerical +'.png’, image_cv2)
    if result == True:
        print(“File saved successfully”)
    else:
        print(“Error in saving file”)

# %%
[x for x in text if re.search(r'[0-9]', x)]

# %%
crop_row_235 = np.load('crop_row_235.npy')

print(crop_row_235.shape)

# %%
plt.imshow(crop_row_235)

# %%
# Read the PNG Image in BGR format
img = cv2.imread("label_26.png")

# Print the Shape of image as it is a Numpy Array
print("Image Shape:", img.shape)
# Out:
# Image Shape: (480, 640, 3)

# %%
plt.imshow(img[:,:,2])

# %%
result = cv2.imwrite(r'\dogs-v-cats\dog.100.png’, image_cv2)
if result == True:
    print(“File saved successfully”)
else:
    print(“Error in saving file”)

# %%
# python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")

# %%
# Folder Path

# %%
# Create test directories

pos_test_dir = "pos_test/"
neg_test_dir = "neg_test/"



path_pos_test = os.path.join(parent_dir, pos_test_dir)
path_neg_test = os.path.join(parent_dir, neg_test_dir)

os.mkdir(path_pos_test)
os.mkdir(path_neg_test)

# %%
pos_train_files = pos_files_sorted[:800]
neg_train_files = neg_files_sorted[:800]
